# %% [markdown]
# ## Import Necessary Packages

# %%
import string
import re
import numpy as np
from collections import Counter#This package has Counter method, to check frequence of word in text

# %% [markdown]
# #### Reading all words, for this we need vocabulory dictionary

# %%
#read corpus text file
def read_corpus(filename):
    with open(filename,'r', encoding='utf-8') as file:
        lines = file.readlines()
        
        #Get words for each line
        words =[]
        for word in lines:
            words += re.findall(r'\w+',word.lower())
    return words

#Invoke this function
corpus = read_corpus(r'big.txt')

# %%
corpus
# Out:
# ['the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'moby',
#  'dick',
#  'or',
#  'the',
#  'whale',
#  'by',
#  'herman',
#  'melville',
#  'this',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  'you',
#  'may',
#  'copy',
#  'it',
#  'give',
#  'it',
#  'away',
#  'or',
#  're',
#  'use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'license',
#  'included',
#  'with',
#  'this',
#  'ebook',
#  'or',
#  'online',
#  'at',
#  'www',
#  'gutenberg',
#  'org',
#  'title',
#  'moby',
#  'dick',
#  'or',
#  'the',
#  'whale',
#  'author',
#  'herman',
#  'melville',
#  'release',
#  'date',
#  'december',
#  '25',
#  '2008',
#  'ebook',
#  '2701',
#  'last',
#  'updated',
#  'december',
#  '3',
#  '2017',
#  'language',
#  'english',
#  'character',
#  'set',
#  'encoding',
# ...

# %%
#To check the lenght of corpus
len(corpus)
# Out:
# 222663

# %%
## Create our vocabulary for Unique words(Removing duplicates)
vocab = set(corpus)#we know set only have unique values, it removes duplicates
len(vocab)
# Out:
# 17647

# %%
### To see how many times words appear in our corpus (text)(Checking word frequency)
words_count = Counter(corpus)
# word_count['by']
# word_count['load']
words_count['for']#'for' appears 1644 times
# Out:
# 1644

# %% [markdown]
# ## Imp: Calculate word probability
# first we have to find out Total no. of words once again
# 1:P(word) = count(word)/N
#
# example:
# 'by' lets assume we have frequency of 10
# Total no. of words overall = 1000
#
# 10/1000 = 1.002 (This is the 'by' probability)

# %%
#To calculate the Total No. of words
# word_count.values()
total_no_words = float(sum(words_count.values()))

# %%
word_probabilities = {word:words_count[word]/total_no_words for word in words_count.keys()}

# %%
word_probabilities
# Out:
# {'the': 0.06603252448767868,
#  'project': 0.0004086893646452262,
#  'gutenberg': 0.0004221626404027611,
#  'ebook': 4.4910919191783095e-05,
#  'of': 0.030278941719100165,
#  'moby': 0.0004041982727260479,
#  'dick': 0.0004041982727260479,
#  'or': 0.003579400259585113,
#  'whale': 0.005524043060589321,
#  'by': 0.005488114325235894,
#  'herman': 1.796436767671324e-05,
#  'melville': 1.796436767671324e-05,
#  'this': 0.006462681271697588,
#  'is': 0.007863901950481221,
#  'for': 0.007383355115129142,
#  'use': 0.0002200635040397372,
#  'anyone': 2.694655151506986e-05,
#  'anywhere': 7.185747070685296e-05,
#  'at': 0.005995607712103043,
#  'no': 0.002667708599991916,
#  'cost': 1.796436767671324e-05,
#  'and': 0.029268446037285047,
#  'with': 0.00794474160502643,
#  'almost': 0.000884745108078127,
#  'restrictions': 8.98218383835662e-06,
#  'whatsoever': 3.143764343424817e-05,
#  'you': 0.004302466058572821,
#  'may': 0.001145228439390469,
#  'copy': 8.533074646438789e-05,
# ...

# %%
#To check the probability of each word
word_probabilities['the']
# Out:
# 0.06603252448767868

# %%
word_probabilities['by']
# Out:
# 0.005488114325235894

# %% [markdown]
# ## Auto-Correct Operations

# %% [markdown]
# ## 1.Split Operation
# first split word into two components
# [('','hello'),('h','ello'),('he','llo'),('hel','lo'),('hell','o'),('hello','')]

# %%
def split(word):#hello 
    return [(word[:i],word[i:]) for i in range(len(word)+1)]

# %%
print(split("hello"))
# Out:
# [('', 'hello'), ('h', 'ello'), ('he', 'llo'), ('hel', 'lo'), ('hell', 'o'), ('hello', '')]

# %%
print(split("why"))
# Out:
# [('', 'why'), ('w', 'hy'), ('wh', 'y'), ('why', '')]

# %%
print(split("python"))
# Out:
# [('', 'python'), ('p', 'ython'), ('py', 'thon'), ('pyt', 'hon'), ('pyth', 'on'), ('pytho', 'n'), ('python', '')]

# %% [markdown]
# ## 2 Delete Operation

# %%
def delete(word):
    return [left+right[1:] for left,right in split(word) if right]

# %%
print(delete('hello'))
# Out:
# ['ello', 'hllo', 'helo', 'helo', 'hell']

# %%
print(split('why'))
print(delete('why'))
# Out:
# [('', 'why'), ('w', 'hy'), ('wh', 'y'), ('why', '')]
# ['hy', 'wy', 'wh']

# %%
print(split('python'))
print(delete('python'))
# Out:
# [('', 'python'), ('p', 'ython'), ('py', 'thon'), ('pyt', 'hon'), ('pyth', 'on'), ('pytho', 'n'), ('python', '')]
# ['ython', 'pthon', 'pyhon', 'pyton', 'pythn', 'pytho']

# %% [markdown]
# ## 3 Swap Operation

# %%
#NOTE: we can't swap one character, hy == yh
def swap(word):
    return [left + right[1] + right[0] + right[2:] for left,right in split(word) if len(right) > 1]

# %%
print(swap('why'))
# Out:
# ['hwy', 'wyh']
